# %% [markdown]
# <a href="https://colab.research.google.com/github/NoeBaru/CampusS.T.E.M/blob/main/tiktok_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Programma la tua prima rete neurale
#
#
# ![logo1081.png](attachment:logo1081.png)

# %% [markdown]
# <font color="orange" size=5><center>Alessandro Cossard - TikTok Exploratory Data Analysis </center></font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#importo i dati in un dataframe

# %%
#from google.colab import files

#uploaded = files.upload()

# %%
df=pd.read_csv('tiktok.csv')

# %%
df
# Out:
#                     track_id                         track_name  \
# 0     6kVuF2PYLuvl9T85XjNbaO            Lay It Down Gmix - Main
# 1     1RGIjMFMgJxkZHMDXVYzOJ             Bartender (feat. Akon)
# 2     1RGIjMFMgJxkZHMDXVYzOJ             Bartender (feat. Akon)
# 3     1dIWPXMX4kRHj6Dt2DStUQ       Chosen (feat. Ty Dolla $ign)
# 4     4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# ...                      ...                                ...
# 6741  1lNHWPDvKEbamKezpLq7HW                no song without you
# 6742  7gd01LMH2gBcoDngSt8sq9  Next To You (feat. Justin Bieber)
# 6743  5PYQUBXc7NYeI1obMKSJK0                  Never Really Over
# 6744  37f4ITSlgPX81ad2EvmVQr                         Fight Song
# 6745  60jpDubMmVyR5molJp2TCm      Ice Cream (with Selena Gomez)
#
#                    artist_id     artist_name                album_id  \
# 0     1Xfmvd48oOhEWkscWyEbh9           Lloyd  43C6GVlhXG4KfZuEbxty3r
# ...

# %%
df['track_name']
# Out:
# 0                 Lay It Down Gmix - Main
# 1                  Bartender (feat. Akon)
# 2                  Bartender (feat. Akon)
# 3            Chosen (feat. Ty Dolla $ign)
# 4           Tie Me Down (with Elley Duhé)
#                       ...
# 6741                  no song without you
# 6742    Next To You (feat. Justin Bieber)
# 6743                    Never Really Over
# 6744                           Fight Song
# 6745        Ice Cream (with Selena Gomez)
# Name: track_name, Length: 6746, dtype: object

# %%
df['track_name'].value_counts().nlargest(20)
# Out:
# Don't Start Now                           26
# What You Know Bout Love                   24
# drivers license                           23
# No Idea                                   23
# OUT WEST (feat. Young Thug)               23
# Put Your Records On                       22
# Tap In                                    20
# death bed (coffee for your head)          19
# Party Girl                                19
# Adderall (Corvette Corvette)              19
# Supalonely                                19
# Toosie Slide                              18
# Buss It                                   18
# Mood (feat. iann dior)                    17
# Peaches (feat. Daniel Caesar & Giveon)    17
# Marikit                                   17
# Say So                                    17
# She Make It Clap                          16
# 34+35                                     16
# Dangerous                                 16
# Name: track_name, dtype: int64

# %%
#top 20 tracks
plt.bar(df['track_name'][:20],df['track_name'].value_counts().nlargest(20))
plt.xticks(rotation=90)
plt.show()

# %%
#top 50 artists
plt.bar(df['artist_name'][:50],df['track_name'].value_counts().nlargest(50))
plt.xticks(rotation=90)
plt.show()

# %%
df.corr()
# Out:
# <ipython-input-12-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   duration  popularity  danceability    energy       key  \
# duration          1.000000    0.007601     -0.158623  0.060148  0.028758
# popularity        0.007601    1.000000     -0.094163 -0.033401  0.033837
# danceability     -0.158623   -0.094163      1.000000 -0.009338  0.009494
# energy            0.060148   -0.033401     -0.009338  1.000000  0.048625
# key               0.028758    0.033837      0.009494  0.048625  1.000000
# loudness          0.039069    0.120266      0.004259  0.705191  0.040888
# mode              0.040617   -0.042006     -0.014135 -0.057658 -0.158493
# speechiness      -0.251785   -0.026279      0.243024 -0.169477 -0.009415
# ...

# %%
plt.imshow(df.corr(), cmap='binary')
plt.show()
# Out:
# <ipython-input-13-4bdef119a01e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(df.corr(), cmap='binary')
